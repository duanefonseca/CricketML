# %% [markdown]
# <a href="https://colab.research.google.com/github/duanefonseca/CricketML/blob/main/projeto_capacitacao_mini_amostra.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
dados_2014_social_notas = pd.read_csv('/content/ingressantes_2014_dados_ML.csv')

# %%
dados_2014_social_notas
# Out:
#     matricula     Modo Ingresso  semestres_cursados situacao  Ingresso_ENEM  \
# 0       82252      PS ENEM/SISU                   2   evasao              1
# 1       73787     Mudança Curso                   2   evasao              0
# 2       80291      PS ENEM/SISU                  12  formado              1
# 3       81938      PS ENEM/SISU                   8  formado              1
# 4       77028      PS ENEM/SISU                   8  formado              1
# 5       81616      PS ENEM/SISU                  10  formado              1
# 6       81231      PS ENEM/SISU                  12  formado              1
# 7       73807     Mudança Curso                  10  formado              0
# 8       77021      PS ENEM/SISU                   4   evasao              1
# 9       80293      PS ENEM/SISU                   2   evasao              1
# 10      81619      PS ENEM/SISU                  12   evasao              1
# ...

# %%
import seaborn as sns

dados_2014_social_notas.groupby('situacao')['semestres_cursados'].describe()
# Out:
#           count       mean       std  min  25%   50%   75%   max
# situacao
# evasao     33.0   4.212121  3.110040  0.0  2.0   4.0   6.0  12.0
# formado    18.0  10.111111  1.875191  8.0  8.0  10.0  12.0  14.0

# %%
sns.boxplot(x='situacao', y='semestres_cursados', data=dados_2014_social_notas)
# Out:
# <Axes: xlabel='situacao', ylabel='semestres_cursados'>
